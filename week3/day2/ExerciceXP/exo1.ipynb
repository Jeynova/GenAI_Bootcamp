# %% [markdown]
# Exercises XP
#
# Last Updated: November 20th, 2024
#
# 👩‍🏫 👩🏿‍🏫 What You'll learn
#
#     Understanding and calculating the determinant and inverse of matrices.
#     Application of these concepts in linear algebra and their significance.
#
#
# 🛠️ What you will create
#
#     Practical examples demonstrating the computation of matrix determinants and inverses using NumPy, applying these concepts to solve real-world problems.
#
#
# 🌟 Exercise 1 : Matrix Operations
# Instructions
#
# In this exercise, you'll work with a 3x3 matrix. Here's a brief explanation of the concepts:
#
#     Determinant: The determinant is a value that can be computed from the elements of a square matrix. It provides important information about the matrix, such as whether it has an inverse, and is used in various areas like linear algebra and calculus. To understand more about it you can watch this video.
#     Inverse of a Matrix: The inverse of a matrix is a matrix that, when multiplied with the original matrix, results in an identity matrix. Not all matrices have inverses. The inverse is crucial in solving systems of linear equations.
#
# Create a 3x3 matrix and perform the following operations:
#
#     Calculate the determinant.
#     Find the inverse of the matrix.
#
#
# 🌟 Exercise 2 : Statistical Analysis
# Instructions
#
# In this exercise, you'll calculate statistical measures for a dataset:
#
#     Mean: The average value of a dataset.
#     Median: The middle value in a dataset when it is arranged in ascending or descending order.
#     Standard Deviation: A measure of the amount of variation or dispersion in a set of values.
#
# Using NumPy, generate an array of 50 random numbers and compute:
#
#     The mean and median.
#     The standard deviation.
#
#
# 🌟 Exercise 3 : Date Manipulation
# Instructions
#
# Create a NumPy array of dates for the month of January 2023. Convert these dates to another format (e.g., YYYY/MM/DD).
#
#
# 🌟 Exercise 4 : Data Manipulation with NumPy and Pandas
# Instructions
#
# Create a DataFrame with random numbers and perform:
#
#     Conditional selection of data.
#     Aggregation functions like sum and average.
#
#
# 🌟 Exercise 5 : Image Representation
# Instructions
#
# Explain how images are represented in NumPy arrays and demonstrate with a simple example (e.g., creating a 5x5 grayscale image).
#
#
# 🌟 Exercise 6 : Basic Hypothesis Testing
# Instructions
#
# Create a sample dataset to test the effectiveness of a new training program on employee productivity:
#
# import numpy as np
#
# # Productivity scores of employees before the training program
# productivity_before = np.random.normal(loc=50, scale=10, size=30)
#
# # Productivity scores of the same employees after the training program
# productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)
#
# # Your task is to formulate a hypothesis regarding the training program's effectiveness
# # and test it using basic statistical functions in NumPy.
#
#
#
# Given a dataset, formulate a simple hypothesis and test it using basic statistical functions in NumPy.
#
#
# 🌟 Exercise 7 : Complex Array Comparison
# Instructions
#
# Create two arrays and perform element-wise comparison to find which elements are greater in the first array.
#
# The expected output is a boolean array showing which elements in the first array are greater than the corresponding elements in the second array.
#
#
# 🌟 Exercise 8 : Time Series Data Manipulation
# Instructions
#
# Generate time series data for the year 2023. Demonstrate slicing for the following intervals:
#
#     January to March
#     April to June
#     July to September
#     October to December
#
# Generate a time series data for a specific period and demonstrate how to slice this data for different intervals.
#
#
# 🌟 Exercise 9 : Data Conversion
# Instructions
#
# Demonstrate how to convert a NumPy array to a Pandas DataFrame and vice versa.
#
#
# 🌟 Exercise 10 : Basic Visualization
# Instructions
#
# Use Matplotlib to visualize a simple dataset created with NumPy (e.g., a line graph of random numbers).

# %%
import numpy as np
from scipy import stats
import seaborn as sns
from scipy.stats import skew, kurtosis
import pandas as pd
import time
import matplotlib.pyplot as plt
from PIL import Image
from scipy.stats import ttest_rel

# %%
matrix = np.array([[4, 2, 1], [3, 5, 7], [1, 1, 1]])
det = np.linalg.det(matrix)
inv = np.linalg.inv(matrix)

print("Déterminant :", det)
print("Inverse :\n", inv)
# Out:
# Déterminant : -1.9999999999999998
# Inverse :
#  [[ 1.   0.5 -4.5]
#  [-2.  -1.5 12.5]
#  [ 1.   1.  -7. ]]

# %%
random_data = np.random.rand(50)
print("Moyenne :", np.mean(random_data))
print("Médiane :", np.median(random_data))
print("Écart-type :", np.std(random_data))
# Out:
# Moyenne : 0.6067720531356935
# Médiane : 0.610422409934327
# Écart-type : 0.2805394025053309

# %%
dates = pd.date_range('2023-01-01', '2023-01-31', freq='D')
formatted_dates = dates.strftime('%Y/%m/%d')
print(formatted_dates)
# Out:
# Index(['2023/01/01', '2023/01/02', '2023/01/03', '2023/01/04', '2023/01/05',
#        '2023/01/06', '2023/01/07', '2023/01/08', '2023/01/09', '2023/01/10',
#        '2023/01/11', '2023/01/12', '2023/01/13', '2023/01/14', '2023/01/15',
#        '2023/01/16', '2023/01/17', '2023/01/18', '2023/01/19', '2023/01/20',
#        '2023/01/21', '2023/01/22', '2023/01/23', '2023/01/24', '2023/01/25',
#        '2023/01/26', '2023/01/27', '2023/01/28', '2023/01/29', '2023/01/30',
#        '2023/01/31'],
#       dtype='object')

# %%
# Out:
#             0.561587  0.051946  0.859620  0.936115  0.951239  0.604843  \
# 2023/01/01  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/02  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/03  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/04  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/05  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/06  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/07  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/08  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/09  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/10  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/11  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/12  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/13  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/14  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/15  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/16  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/17  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/18  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/19  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/20  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/21  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/22  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/23  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/24  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/25  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/26  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/27  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/28  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/29  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/30  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
# 2023/01/31  0.561587  0.051946   0.85962  0.936115  0.951239  0.604843
#
#             0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275  \
# 2023/01/01  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/02  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/03  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/04  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/05  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/06  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/07  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/08  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/09  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/10  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/11  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/12  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/13  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/14  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/15  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/16  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/17  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/18  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/19  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/20  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/21  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/22  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/23  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/24  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/25  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/26  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/27  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/28  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/29  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/30  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
# 2023/01/31  0.919803  0.498014  0.004517  0.842707  ...  0.388427  0.835275
#
#             0.607683  0.141575  0.832760  0.989064  0.882704  0.996091  \
# 2023/01/01  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/02  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/03  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/04  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/05  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/06  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/07  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/08  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/09  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/10  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/11  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/12  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/13  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/14  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/15  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/16  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/17  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/18  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/19  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/20  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/21  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/22  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/23  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/24  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/25  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/26  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/27  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/28  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/29  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/30  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
# 2023/01/31  0.607683  0.141575   0.83276  0.989064  0.882704  0.996091
#
#             0.934446  0.068663
# 2023/01/01  0.934446  0.068663
# 2023/01/02  0.934446  0.068663
# 2023/01/03  0.934446  0.068663
# 2023/01/04  0.934446  0.068663
# 2023/01/05  0.934446  0.068663
# 2023/01/06  0.934446  0.068663
# 2023/01/07  0.934446  0.068663
# 2023/01/08  0.934446  0.068663
# 2023/01/09  0.934446  0.068663
# 2023/01/10  0.934446  0.068663
# 2023/01/11  0.934446  0.068663
# 2023/01/12  0.934446  0.068663
# 2023/01/13  0.934446  0.068663
# 2023/01/14  0.934446  0.068663
# 2023/01/15  0.934446  0.068663
# 2023/01/16  0.934446  0.068663
# 2023/01/17  0.934446  0.068663
# 2023/01/18  0.934446  0.068663
# 2023/01/19  0.934446  0.068663
# 2023/01/20  0.934446  0.068663
# 2023/01/21  0.934446  0.068663
# 2023/01/22  0.934446  0.068663
# 2023/01/23  0.934446  0.068663
# 2023/01/24  0.934446  0.068663
# 2023/01/25  0.934446  0.068663
# 2023/01/26  0.934446  0.068663
# 2023/01/27  0.934446  0.068663
# 2023/01/28  0.934446  0.068663
# 2023/01/29  0.934446  0.068663
# 2023/01/30  0.934446  0.068663
# 2023/01/31  0.934446  0.068663
#
# [31 rows x 50 columns]

# %%
df = pd.DataFrame(np.random.rand(5, 4), columns=list("ABCD"))
print("DataFrame initial :\n", df)
print("Sélection A > 0.5 :\n", df[df["A"] > 0.5])
print("Somme par colonne :", df.sum())
print("Moyenne par colonne :", df.mean())
# Out:
# DataFrame initial :
#            A         B         C         D
# 0  0.077335  0.433298  0.865816  0.682584
# 1  0.714424  0.503929  0.977957  0.808031
# 2  0.712616  0.041333  0.908061  0.624942
# 3  0.262914  0.109891  0.565554  0.550597
# 4  0.549157  0.823587  0.122359  0.108491
# Sélection A > 0.5 :
#            A         B         C         D
# 1  0.714424  0.503929  0.977957  0.808031
# 2  0.712616  0.041333  0.908061  0.624942
# 4  0.549157  0.823587  0.122359  0.108491
# Somme par colonne : A    2.316447
# B    1.912038
# C    3.439747
# D    2.774645
# dtype: float64
# Moyenne par colonne : A    0.463289
# B    0.382408
# C    0.687949
# D    0.554929
# dtype: float64

# %% [markdown]
# Une image en niveaux de gris (grayscale) est représentée comme une matrice 2D, où :
#
#     chaque valeur entière représente l'intensité d'un pixel,
#
#     0 = noir, 255 = blanc,
#
#     les valeurs intermédiaires sont des nuances de gris.

# %%
image = np.zeros((7, 7), dtype=np.uint8)
image[3, :] = 255 
image[:, 3] = 255

plt.imshow(image, cmap='gray')
plt.title("Croix blanche sur fond noir")
plt.axis('off')
plt.show()

# %%
# generer 30 scores avant formation autour de 50
# utiliser une graine pour garder les memes valeurs
np.random.seed(0)
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# simuler scores apres formation en ajoutant en moyenne 5 points
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

# h0 la formation ne change rien
# h1 la formation augmente la productivite

# moyenne avant
mean_before = np.mean(productivity_before)
# moyenne apres
mean_after = np.mean(productivity_after)

# ecart type avant
std_before = np.std(productivity_before)
# ecart type apres
std_after = np.std(productivity_after)

# difference entre les deux moyennes
diff = mean_after - mean_before

# afficher resultats
print(f"moyenne avant : {mean_before:.2f}")
print(f"moyenne apres : {mean_after:.2f}")
print(f"difference moyenne : {diff:.2f}")

# test t pour comparer les memes personnes avant et apres
stat, p_value = ttest_rel(productivity_after, productivity_before)
print(f"statistique t = {stat:.2f}, p-value = {p_value:.4f}")
# Out:
# moyenne avant : 54.43
# moyenne apres : 58.56
# difference moyenne : 4.13
# statistique t = 8.25, p-value = 0.0000

# %%
a1 = np.array([1, 4, 6, 8])
a2 = np.array([2, 3, 6, 5])
print("Comparaison :", a1 > a2)
# Out:
# Comparaison : [False  True False  True]

# %%
# creer une serie de dates pour toute l annee 2023
dates = pd.date_range(start="2023-01-01", end="2023-12-31", freq="D")

# generer des valeurs entre -5 et 35 pour chaque jour
values = np.random.uniform(low=-5, high=35, size=len(dates))

# creer un dataframe avec les dates comme index
df = pd.DataFrame({'Date': dates, 'Value': values}).set_index('Date')

# definir les trimestres avec leur date de debut et de fin
quarters = {
    "Janvier - Mars": ("2023-01-01", "2023-03-31"),
    "Avril - Juin": ("2023-04-01", "2023-06-30"),
    "Juillet - Septembre": ("2023-07-01", "2023-09-30"),
    "Octobre - Decembre": ("2023-10-01", "2023-12-31")
}

# afficher les premieres lignes de chaque trimestre
for name, (start, end) in quarters.items():
    data = df[start:end]
    print(f"\n{name} :")
    print(data.head())

# preparer une figure avec 4 graphiques
plt.figure(figsize=(12, 8))
colors = ['blue', 'green', 'orange', 'red']

# afficher chaque trimestre dans un graphique
for i, (name, (start, end)) in enumerate(quarters.items(), 1):
    data = df[start:end]
    plt.subplot(2, 2, i)
    plt.plot(data.index, data['Value'], color=colors[i-1])
    plt.title(name)
    plt.xlabel("Date")
    plt.xticks(rotation=45)
    plt.ylabel("Valeur")
    plt.grid(True)

# ajuster les espaces entre les graphiques
plt.tight_layout()
# afficher la figure
plt.show()
# Out:
# Janvier - Mars :
#                 Value
# Date
# 2023-01-01   6.845608
# 2023-01-02  -0.250891
# 2023-01-03   7.719327
# 2023-01-04  11.570520
# 2023-01-05  -2.434100
#
# Avril - Juin :
#                 Value
# Date
# 2023-04-01  24.199622
# 2023-04-02   1.865187
# 2023-04-03  15.841464
# 2023-04-04  -2.826480
# 2023-04-05   2.999861
#
# Juillet - Septembre :
#                 Value
# Date
# 2023-07-01   6.685901
# 2023-07-02   4.633151
# 2023-07-03  -0.988242
# 2023-07-04  -4.342815
# 2023-07-05  32.181173
#
# Octobre - Decembre :
#                 Value
# Date
# 2023-10-01  -3.585503
# 2023-10-02  12.216098
# 2023-10-03  15.400674
# 2023-10-04  16.447100
# 2023-10-05  22.255700

# %%
x = np.arange(1, 21)
y = np.random.randint(10, 100, size=20)

plt.figure(figsize=(10, 5))
plt.plot(x, y, marker='o', linestyle='-', color='purple', label='Valeurs aléatoires')

plt.title("Graphe de valeurs aléatoires")
plt.xlabel("Index")
plt.ylabel("Valeur")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
