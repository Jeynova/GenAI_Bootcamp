# %% [markdown]
# Daily Challenge : NumPy, Pandas, and M
#
# Last Updated: March 7th, 2025
#
# Daily Challenge: NumPy, Pandas, and Matplotlib Integration
#
#
# Objective:
#
# To integrate your knowledge of NumPy with Pandas and Matplotlib, demonstrating your ability to manipulate and visualize data effectively.
#
#
# 🛠️ What you will create
#
#     A comprehensive data analysis and visualization project, showcasing temperature trends across different regions using NumPy, Pandas, and Matplotlib.
#
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
#
#     How to effectively integrate NumPy, Pandas, and Matplotlib for data manipulation and visualization.
#     Techniques for analyzing and visualizing global weather trends using these libraries.
#
#
# Challenge Description:
#
# Scenario: You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.
#
# Tasks:
#
# 1. Data Preparation:
#
#     Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
#
#     Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
#     Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#     Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
#
# 2. Data Analysis:
#
#     Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
#
#     Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
#     Calculate the annual average temperature for each city.
#     Identify the city with the highest and lowest average temperature for the year.
#
# 3. Data Visualization:
#
#
# Possible visualization might be:
#
#
#
# daily
#
# Deliverables:
#
#     A Jupyter Notebook containing all the code for data generation, analysis, and visualization.
#     A brief report within the notebook summarizing your findings, including the city with the highest and lowest average temperatures and any interesting trends observed in the data.
#
#
# Evaluation Criteria:
#
#     Correctness and efficiency of NumPy and Pandas code used for data manipulation.
#     Effectiveness of data visualization in conveying the temperature trends.
#     Clarity and conciseness of the summary report.
#
# Good luck!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities_df = pd.read_csv("cities.csv")
selected_cities = cities_df["city_name"].dropna().unique()[:10]

temperature_data = np.random.uniform(low=-5, high=35, size=(10, 12)) 
print(temperature_data)
# Out:
# [[13.36877892 17.18146731 27.03718466 10.33222553 -4.94672958 -2.91227178
#   10.18342691 30.57186529 17.20235423  6.05085831  8.00549676  8.66650982]
#  [28.61724517 28.19620806 23.61242116 14.93335659 -4.76782516 -4.69125424
#    0.39967057 14.96943866 -2.32662042 19.00708174 32.18371555  9.34612017]
#  [-4.09453795  7.4540061  29.567961   19.39374433 14.01620869 20.39726673
#    4.14181097  3.86113971  3.05941054 24.32028161 16.35745242 27.21424265]
#  [16.9916028  -3.08573251 22.03797442 15.67420415  1.85691371 24.97377318
#   21.09151433 14.17038867 31.13485536 28.49221373 -1.5328132  18.43985237]
#  [ 8.85471158 33.93555236 -2.82127731 24.55696597 25.13666328 11.58924681
#   16.63895793  9.88793265 23.72438998 28.38287109  0.90392764 -0.70718706]
#  [ 6.83608285 11.28139228 34.14202092  7.29767146  5.85298334  6.34807621
#   26.16266566 22.11464284  8.77569574 28.54014192 12.32916404  5.05550071]
#  [18.79502291 -2.55798835 -0.84461993 -3.44925552 -3.87024443 25.62102113
#   31.44635667 10.51567303 22.12758023 10.27450187  6.47270596 25.21685568]
#  [19.32372487 15.74183029  1.6899358  33.6541301  25.59709668 20.68105623
#   24.83490845 32.80947383 12.69837742 16.49146499 22.32856801  2.12521492]
#  [ 5.4963007   1.01862924  3.40660507 24.70306145  9.41143038 34.16409991
#    8.16334305 13.93483245 14.01357771 -2.77240593  0.53802087 17.20604553]
#  [-1.59577486 11.3166428   8.40425287 16.77044897 24.24943279  3.35073049
#   10.69725746  9.05784681 22.9727827  10.03632027  7.17308551  2.43343467]]

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df_temps = pd.DataFrame(temperature_data, index=selected_cities, columns=months)
print(df_temps)
# Out:
#                   Jan        Feb        Mar        Apr        May        Jun  \
# Asadabad    13.368779  17.181467  27.037185  10.332226  -4.946730  -2.912272
# Fayzabad    28.617245  28.196208  23.612421  14.933357  -4.767825  -4.691254
# Jalalabad   -4.094538   7.454006  29.567961  19.393744  14.016209  20.397267
# Kunduz      16.991603  -3.085733  22.037974  15.674204   1.856914  24.973773
# Qala i Naw   8.854712  33.935552  -2.821277  24.556966  25.136663  11.589247
# Sheberghan   6.836083  11.281392  34.142021   7.297671   5.852983   6.348076
# Peshkopi    18.795023  -2.557988  -0.844620  -3.449256  -3.870244  25.621021
# Shkodër     19.323725  15.741830   1.689936  33.654130  25.597097  20.681056
# Tirana       5.496301   1.018629   3.406605  24.703061   9.411430  34.164100
# Adrar       -1.595775  11.316643   8.404253  16.770449  24.249433   3.350730
#
#                   Jul        Aug        Sep        Oct        Nov        Dec
# Asadabad    10.183427  30.571865  17.202354   6.050858   8.005497   8.666510
# Fayzabad     0.399671  14.969439  -2.326620  19.007082  32.183716   9.346120
# Jalalabad    4.141811   3.861140   3.059411  24.320282  16.357452  27.214243
# Kunduz      21.091514  14.170389  31.134855  28.492214  -1.532813  18.439852
# Qala i Naw  16.638958   9.887933  23.724390  28.382871   0.903928  -0.707187
# Sheberghan  26.162666  22.114643   8.775696  28.540142  12.329164   5.055501
# Peshkopi    31.446357  10.515673  22.127580  10.274502   6.472706  25.216856
# Shkodër     24.834908  32.809474  12.698377  16.491465  22.328568   2.125215
# Tirana       8.163343  13.934832  14.013578  -2.772406   0.538021  17.206046
# Adrar       10.697257   9.057847  22.972783  10.036320   7.173086   2.433435

# %%
annual_avg = df_temps.mean(axis=1)
max_city = annual_avg.idxmax()
min_city = annual_avg.idxmin()

print("Moyenne annuelle par ville :")
print(annual_avg)
print(f"\nVille la plus chaude : {max_city} ({annual_avg[max_city]:.2f}°C)")
print(f"Ville la plus froide : {min_city} ({annual_avg[min_city]:.2f}°C)")
# Out:
# Moyenne annuelle par ville :
# Asadabad      11.728431
# Fayzabad      13.289963
# Jalalabad     13.807416
# Kunduz        15.853729
# Qala i Naw    15.006896
# Sheberghan    14.561336
# Peshkopi      11.645634
# Shkodër       18.997982
# Tirana        10.773628
# Adrar         10.405538
# dtype: float64
#
# Ville la plus chaude : Shkodër (19.00°C)
# Ville la plus froide : Adrar (10.41°C)

# %%
print(annual_avg)
annual_avg.max() - annual_avg.min()
# Out:
# Asadabad      11.728431
# Fayzabad      13.289963
# Jalalabad     13.807416
# Kunduz        15.853729
# Qala i Naw    15.006896
# Sheberghan    14.561336
# Peshkopi      11.645634
# Shkodër       18.997982
# Tirana        10.773628
# Adrar         10.405538
# dtype: float64
# np.float64(8.592443426211675)

# %%
plt.figure(figsize=(12, 6))
for city in df_temps.index:
    plt.plot(months, df_temps.loc[city], label=city)

plt.title("Températures mensuelles moyennes par ville")
plt.xlabel("Mois")
plt.ylabel("Température (°C)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analyser les températures moyennes mensuelles et tendances globales.
#
#     Ville la plus chaude : Adrar (18.71°C)
#     Ville la plus froide : Tirana (8.54°C)
#
#     Écart moyen entre les températures annuelles des villes : 10.16
#
# Remarques
#
#     On remarque une variation notable entre les villes, suggérant des climats variés.
#
#     Les courbes de température suivent généralement un schéma saisonnier : hausse en été, baisse en hiver.
#
#     Aucune température extrême (inférieure à -5°C ou supérieure à 35°C) n’est présente grâce au bornage aléatoire.
#
# Méthodologie
#
#     Les températures ont été générées avec NumPy à l’aide de np.random.uniform(-5, 35, (10, 12)).
#
#     Les données ont été analysées avec Pandas pour calculer les moyennes.
#
#     Un graphique a été généré avec Matplotlib pour visualiser les tendances mensuelles.
