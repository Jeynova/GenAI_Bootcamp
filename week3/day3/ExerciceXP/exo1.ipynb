# %% [markdown]
# Exercises XP
#
# Last Updated: January 27th, 2025
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
#
#     How to apply various statistical functions using SciPy
#     Understanding probability distributions and hypothesis testing
#     Analyzing data with regression, ANOVA, and correlation methods
#
#
# 🛠️ What you will create
#
# You will create a series of Python scripts that perform different statistical analyses, including data exploration, hypothesis testing, linear regression, ANOVA, and more.
#
#
# 🌟 Exercise 1: Basic Usage of SciPy
#
#     Task: Import the SciPy library and explore its version.
#
#
# 🌟 Exercise 2: Descriptive Statistics
#
#     Task: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
#     Sample Dataset:
#
# data = [12, 15, 13, 12, 18, 20, 22, 21]
#
#
# 🌟 Exercise 3: Understanding Distributions
#
#     Task: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.
#     Code Example:
#
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm
#
# # complete your code here
#
#
# 🌟 Exercise 4: T-Test Application
#
#     Task: Perform a T-test on two sets of randomly generated data.
#     Code Example:
#
# data1 = np.random.normal(50, 10, 100)
# data2 = np.random.normal(60, 10, 100)
#
# # complete your code here
#
#
# 🌟 Exercise 5: Linear Regression Analysis
#
# Objective: Apply linear regression to a dataset and interpret the results.
#
#     Task: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
#     Dataset:
#         house_sizes: [50, 70, 80, 100, 120] (in square meters)
#         house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
#     Questions:
#     What is the slope and intercept of the regression line?
#     Predict the price of a house that is 90 square meters.
#     Interpret the meaning of the slope in the context of housing prices.
#
#
# 🌟 Exercise 6: Understanding ANOVA
#
# Objective: Test understanding of ANOVA and its application.
#
#     Task: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
#     Dataset:
#         fertilizer_1: [5, 6, 7, 6, 5]
#         fertilizer_2: [7, 8, 7, 9, 8]
#         fertilizer_3: [4, 5, 4, 3, 4]
#     Questions:
#     Perform an ANOVA test on the given data. What are the F-value and P-value?
#     Based on the P-value, do the fertilizers have significantly different effects on plant growth?
#     Explain what would happen if the P-value were greater than 0.05.
#
#
# 🌟 Exercise 7: Probability Distributions (Optional)
#
#     Work with a binomial distribution: calculate probabilities for different numbers of successes.
#     Example: Calculating the probability of getting exactly 5 heads in 10 coin flips.
#
#
# 🌟 Exercise 8: Correlation Coefficients (Optional)
#
#     Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.
#     Example in code: data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

# %%
import numpy as np
from scipy import stats
import scipy as sp
import matplotlib.pyplot as plt
from scipy.stats import binom,norm,poisson,expon,pearsonr, spearmanr
import seaborn as sns
import pandas as pd

# %%
print("SciPy version:", sp.__version__)
# Out:
# SciPy version: 1.15.3

# %%
data = [12, 15, 13, 12, 18, 20, 22, 21]

mean_scipy = stats.tmean(data)
median_scipy = np.median(data) 
variance_scipy = stats.tvar(data)
std_dev_scipy = stats.tstd(data)

print("Mean:", mean_scipy)
print("Median:", median_scipy)
print("Variance:", variance_scipy)
print("Standard Deviation:", std_dev_scipy )
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 17.125
# Standard Deviation: 4.138236339311712

# %%
mean = 50
std_dev = 10

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
y = norm.pdf(x, mean, std_dev)

# Tracer la distribution
plt.plot(x, y)
plt.title("Distribution Normale (mean = 50, std_dev = 10)")
plt.xlabel("Valeur")
plt.ylabel("Densité de probabilité")
plt.grid(True)
plt.show()

# %%
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

t_stat, p_val = stats.ttest_ind(data1, data2)

print("T-statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Il y a une différence significative entre les deux groupes.")
else:
    print("Aucune différence significative détectée.")
# Out:
# T-statistic: -5.632880675510489
# P-value: 6.021756418139157e-08
# Il y a une différence significative entre les deux groupes.

# %%
house_sizes = np.array([50, 70, 80, 100, 120])
house_prices = np.array([150000, 200000, 210000, 250000, 280000])

slope, intercept, r_value, p_value, std_err = stats.linregress(house_sizes, house_prices)
predicted_price = slope * 90 + intercept

print("Pente (slope):", slope)
print("Ordonnée à l'origine (intercept):", intercept)
print(f"Prix prédit pour une maison de 90 m²: {predicted_price:.2f}")


plt.scatter(house_sizes, house_prices, color='blue', label='Données')
plt.plot(house_sizes, slope * house_sizes + intercept, color='red', label='Régression linéaire')
plt.xlabel('Taille de la maison (m²)')
plt.ylabel('Prix de la maison')
plt.title("Régression linéaire entre taille de la maison et prix")
plt.legend()
plt.grid(True)
plt.show()

print(f"La pente indique qu'à chaque augmentation de 1 m², le prix de la maison augmente de {slope:.2f} €.")
# Out:
# Pente (slope): 1828.7671232876712
# Ordonnée à l'origine (intercept): 64383.56164383562
# Prix prédit pour une maison de 90 m²: 228972.60
# La pente indique qu'à chaque augmentation de 1 m², le prix de la maison augmente de 1828.77 €.

# %%
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

f_stat, p_val = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)

print("F-statistic:", f_stat)
print("P-value:", p_val)

# Interprétation du P-value
if p_val < 0.05:
    print("Les engrais ont un effet significatif sur la croissance des plantes.")
else:
    print("Il n'y a pas d'effet significatif des engrais sur la croissance des plantes.")

# Visualisation des données avec un boxplot
data = [fertilizer_1, fertilizer_2, fertilizer_3]
labels = ['Fertilizer 1', 'Fertilizer 2', 'Fertilizer 3']

plt.figure(figsize=(8, 6))
plt.boxplot(data, tick_labels=labels)
plt.title("Comparaison de la croissance des plantes en fonction de l'engrais")
plt.xlabel("Type d'engrais")
plt.ylabel("Croissance des plantes (cm)")
plt.grid(True)
plt.show()
# Out:
# F-statistic: 28.52631578947368
# P-value: 2.754267209804844e-05
# Les engrais ont un effet significatif sur la croissance des plantes.

# %%
throw = 10
proba = 0.5
face = 5

prob = binom.pmf(face, throw, proba)

print(f"La probabilité d'obtenir exactement 5 têtes sur 10 lancers est {prob:.4f}")
# Out:
# La probabilité d'obtenir exactement 5 têtes sur 10 lancers est 0.2461

# %%
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

pearson_corr, _ = pearsonr(data['age'], data['income'])
print("Coefficient de corrélation de Pearson:", pearson_corr)

spearman_corr, _ = spearmanr(data['age'], data['income'])
print("Coefficient de corrélation de Spearman:", spearman_corr)
# Out:
# Coefficient de corrélation de Pearson: 0.9996907452347201
# Coefficient de corrélation de Spearman: 0.9999999999999999
