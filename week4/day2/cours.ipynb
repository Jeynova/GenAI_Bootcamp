# %% [markdown]
# 🧠 FICHE DE SYNTHÈSE – COMPRENDRE LA CLASSIFICATION EN MACHINE LEARNING
# 🎯 Objectifs de la leçon
#
#     Comprendre le principe de la classification en ML.
#
#     Connaître la différence entre Lazy Learners et Eager Learners.
#
#     Identifier les types de tâches de classification.
#
#     Explorer les algorithmes de classification les plus utilisés.
#
#     Savoir comment choisir un modèle adapté à son problème.
#
# 🧩 1. Qu’est-ce que la classification ?
#
#     Classification = Prédire une étiquette (classe) parmi un ensemble fini.
#
#     Ex : Est-ce un chat ou un chien ? Le fruit est-il pomme / banane / cerise ?
#
#     Le modèle est entraîné sur des données étiquetées (supervised learning).
#
#     Ensuite, il est testé sur de nouvelles données pour évaluer sa capacité à généraliser.
#
# 🔄 2. Lazy Learners vs. Eager Learners
# Type	Fonctionnement	Exemple	Analogie
# Lazy Learners	Ne construisent pas de modèle à l’avance. Mémorisent juste les données.	KNN	Le tailleur qui attend la commande pour agir
# Eager Learners	Construisent un modèle pendant l’entraînement	Arbres de Décision	Le chef qui prépare les plats à l’avance
# 🗂️ 3. Types de tâches de classification
# Type	Exemple
# Binaire	Spam / Pas Spam, Malade / Pas malade
# Multi-Classe	Chat / Chien / Oiseau
# Multi-Label	Film = Comédie + Action + Thriller
# Déséquilibrée	Fraude (1%) / Transactions normales (99%)
#
# ✅ Challenge : Réponse correcte → c) Le film avec plusieurs genres → Multi-Label
# 🤖 4. Algorithmes de Classification & Exemples
# 📈 Linear / Logistic Regression
#
#     Utilisé pour des cas linéaires simples
#
#     Logistic Regression = prédire une probabilité de classe
#
# 🐝 Naive Bayes
#
#     Très rapide, efficace avec peu de données
#
#     Suppose l’indépendance des features (ce qui est rarement vrai en pratique)
#
#     Idéal pour texte / NLP
#
# 🧑‍🌾 K-Nearest Neighbors (KNN) – Lazy Learner
#
#     Prédit en comparant à ses voisins proches
#
#     Sensible à l’échelle des données (nécessite un scaling)
#
# 🌳 Decision Tree
#
#     Apprentissage eager, facile à interpréter
#
#     Tendance à l’overfitting
#
# 🌲 Random Forest
#
#     Ensemble d’arbres = meilleure robustesse
#
#     Moins interprétable mais souvent très performant
#
# 💥 SVM (Support Vector Machine)
#
#     Recherche le meilleur hyperplan qui sépare les classes
#
#     Excellent pour les données petites à moyennes
#
#     Sensible au scaling et au bruit
#
# ⚖️ 5. Choisir son modèle : quelques repères
# Critère	Modèles conseillés
# Données linéaires	Régression Logistique, SVM (linéaire)
# Relations complexes	Random Forest, SVM (non-linéaire), NN
# Besoin d’interprétation	Régression, Arbres
# Peu de données	Naive Bayes, KNN
# Overfitting à surveiller	Privilégier des modèles réguliers ou ensemblistes
# Besoin de scaling	SVM, KNN, LogisticRegression
# Pas besoin de scaling	Tree-based (Decision Trees, Random Forest)
# 🧪 BONUS – Visualisation des modèles (avec scikit-learn)
#
# Tu as maintenant des exemples concrets pour chaque algo, tous exploitables dans un notebook VS Code ou Jupyter.
#
# Tu veux :
#
#     ✅ Travailler sur un exemple multi-classe (Iris dataset) avec Random Forest ou SVM ?
#
#     ✅ Créer un mini-projet de classification avec ton dataset ?
#
#     ✅ Un schéma récapitulatif des familles de modèles (linéaires / arbres / instance-based / bayésiens) ?
#
# ✅ Petit Quiz de Validation
#
#     Quel est un exemple de modèle lazy learner ?
#     → ✅ KNN
#
#     Quel cas correspond à de la multi-label classification ?
#     → ✅ Un film avec plusieurs genres
#
#     Quelle méthode est la plus interprétable ?
#     → ✅ Decision Tree
#
#     Quelle méthode construit un modèle pendant l’entraînement ?
#     → ✅ Eager learners (comme les Decision Trees)

# %% [markdown]
# 📈 Image 1 – Régression Linéaire (Linear Regression)
#
# Représentation :
#
#     L’axe X montre la taille (Height), l’axe Y le poids (Weight).
#
#     La ligne droite représente un modèle de régression linéaire :
#     wgt = 80 + 2 × hgt
#
# Lien avec le cours :
#
#     📊 Cas d’usage : Predictive Analytics
#
#     Utilisation de la régression pour prédire une variable continue (ici, le poids) à partir d’une autre (la taille).
#
# 🧭 Image 2 – Support Vector Machine (SVM)
#
# Représentation :
#
#     Deux classes :
#     🔴 Classe A (étoiles rouges)
#     🟢 Classe B (triangles verts)
#
#     Une marge entre les deux, avec une hyperplan de séparation au centre.
#
#     Les Support Vectors sont les points les plus proches de la marge.
#
# Lien avec le cours :
#
#     🤖 Cas d’usage : Classification
#
#     SVM est un algorithme de machine learning supervisé utilisé pour classer des données dans différentes catégories (ex. : détection de fraude ou tri d’emails).
#
# 🌳 Image 3 – Arbre de Décision (Decision Tree)
#
# Représentation :
#
#     Chaque nœud pose une question.
#
#     Chaque branche correspond à une réponse (Oui / Non).
#
#     Les feuilles donnent la classification finale (Apple, Orange, Banana...).
#
# Lien avec le cours :
#
#     📚 Cas d’usage : Classification et Décision
#
#     Les arbres de décision sont très utilisés en ML pour prendre des décisions automatisées sur des données catégoriques ou numériques.
#     Exemple dans le cours : détecter le churn ou classer un ticket client.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Données d'entraînement (height en inches, weight en pounds)
height = np.array([50, 55, 60, 65, 67, 70, 72, 75]).reshape(-1, 1)
weight = np.array([100, 115, 130, 145, 150, 160, 165, 170])

# Modèle de régression
model = LinearRegression()
model.fit(height, weight)

# Prédiction
predicted_weight = model.predict(height)

# Affichage
plt.scatter(height, weight, color='black', label='Données réelles')
plt.plot(height, predicted_weight, color='blue', linewidth=2, label='Régression')
plt.xlabel("Height (inches)")
plt.ylabel("Weight (pounds)")
plt.title("Linear Regression - Weight vs Height")
plt.legend()
plt.grid(True)
plt.show()

# Afficher les coefficients
print(f"Intercept (a): {model.intercept_}")
print(f"Slope (b): {model.coef_[0]}")
# Out:
# Intercept (a): -42.989493791786
# Slope (b): 2.8772683858643737

# %%
# SVM Classifier Example
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC

# Données simples pour classification
X, y = datasets.make_blobs(n_samples=30, centers=2, random_state=6)

# Création du modèle SVM
model = SVC(kernel='linear')
model.fit(X, y)

# Tracé
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', s=30)

# Obtenir les coefficients du modèle
w = model.coef_[0]
b = model.intercept_[0]

# Calcul des marges
x_plot = np.linspace(min(X[:, 0]), max(X[:, 0]))
y_decision = -(w[0] * x_plot + b) / w[1]
margin = 1 / np.sqrt(np.sum(w ** 2))
y_margin_up = y_decision + margin
y_margin_down = y_decision - margin

# Affichage de l'hyperplan et des marges
plt.plot(x_plot, y_decision, 'k-')
plt.plot(x_plot, y_margin_up, 'k--')
plt.plot(x_plot, y_margin_down, 'k--')

plt.title("SVM Binary Classification")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()

# %%
# Decision Tree Classifier
from sklearn import tree

# Exemple simple : Caractéristiques de fruits
# [IsYellow, IsOrange, IsLong, IsEasyToPeel]
X = [
    [0, 1, 0, 0],  # Orange
    [0, 1, 0, 1],  # Orange
    [1, 0, 1, 1],  # Banana
    [1, 0, 1, 0],  # Plantain
    [1, 0, 0, 0],  # Apple
    [0, 0, 0, 0],  # Apple
]
y = ['Orange', 'Orange', 'Banana', 'Plantain', 'Apple', 'Apple']

# Création du modèle
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# Affichage de l'arbre
plt.figure(figsize=(10, 6))  # Largeur x Hauteur en pouces
tree.plot_tree(
    clf,
    filled=True,
    feature_names=['Yellow', 'Orange', 'Long', 'EasyToPeel'],
    fontsize=12
)
plt.title("Decision Tree - Fruit Classifier")
plt.show()

# Prédiction d’un fruit
test = [[1, 0, 1, 1]]  # Devrait prédire "Banana"
print("Prédiction :", clf.predict(test)[0])
# Out:
# Prédiction : Banana

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Create some data
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Independent variable (hours studied)
y = 2 * X + 1 + np.random.randn(100, 1) * 2  # Dependent variable (test scores)

# Create a linear regression model
model = LinearRegression()

# Fit the model
model.fit(X, y)

# Make predictions
X_new = np.array([[0], [10]])
y_predict = model.predict(X_new)

# Plotting the results
plt.scatter(X, y, color='blue')  # plot the data points
plt.plot(X_new, y_predict, color='red', linewidth=2)  # plot the regression line
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (y)')
plt.title('Linear Regression Example')
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# Create some data
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Independent variable (e.g., hours studied)
y = (X > 5).astype(np.float64).ravel()  # Dependent variable (e.g., pass/fail)

# Create a logistic regression model
model = LogisticRegression()

# Fit the model
model.fit(X, y)

# Make predictions
X_test = np.linspace(0, 10, 300)
y_prob = model.predict_proba(X_test.reshape(-1, 1))[:, 1]

# Plotting the results
plt.scatter(X, y, color='blue')  # plot the data points
plt.plot(X_test, y_prob, color='red', linewidth=2)  # plot the logistic regression curve
plt.xlabel('Independent Variable (X)')
plt.ylabel('Probability of Class 1 (y)')
plt.title('Logistic Regression Example')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create random data
np.random.seed(0)
X = np.random.randn(20, 2)
Y = np.where(X[:, 0] + X[:, 1] > 0, 1, -1)

# Visualize the data
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("Synthetic Data for Binary Classification")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Create an SVM classifier with a linear kernel
from sklearn import svm
clf = svm.SVC(kernel="linear")

# Train the classifier on the training data
clf.fit(X_train, Y_train)

# Make predictions
Y_pred = clf.predict(X_test)

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# Generate a random binary classification problem.
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0, n_clusters_per_class=1, random_state=42)

# Create a KNN classifier model
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model
knn.fit(X, y)

# We create a mesh of points to visualize the decision boundaries of the KNN classifier
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                 np.arange(y_min, y_max, 0.02))

# Predict class for each point in the mesh
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plotting the results
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Nearest Neighbors Classification')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Sample data
# Features: weight (grams), color (0 = Green, 1 = Yellow, 2 = Red)
# Target: types of fruits
features = np.array([[150, 0], [170, 0], [140, 2], [130, 2], [200, 1], [180, 1]])
labels = np.array(["Apple", "Apple", "Cherry", "Cherry", "Banana", "Banana"])

# don't bother for this step, it is just used to encode string labels to integers
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Creating and training the Naive Bayes model
model = GaussianNB()
model.fit(features, labels_encoded)

# Making predictions
# Let's predict the fruit type for a 160g green fruit and a 190g yellow fruit
predicted = model.predict([[160, 0], [190, 1]])
predicted_labels = label_encoder.inverse_transform(predicted)

print(f"Predictions: {predicted_labels}")
# Out:
# Predictions: ['Apple' 'Banana']

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(max_depth=3, random_state=42)

# Train the classifier on the training data
dt_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = dt_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Random Forest Classifier with 100 trees
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %% [markdown]
# 🧠 Fiche Pratique – Détection de Fraude par Carte Bancaire (Credit Card Fraud Detection)
# 🎯 Objectif
#
# Créer un modèle de Machine Learning pour détecter automatiquement les fraudes sur des transactions bancaires.
#
#     Modèle utilisé : Régression Logistique (Logistic Regression)
#
# 📌 Ce que tu vas apprendre
#
#     Comprendre le problème (classification)
#
#     Collecter, préparer et explorer les données
#
#     Entraîner un modèle de classification
#
#     Évaluer les performances avec des métriques adaptées au cas de la fraude
#
# 🧱 Pourquoi c’est un problème de classification ?
#
# Il s’agit de prédire deux classes :
#
#     0 → Transaction légitime (Not Fraud)
#
#     1 → Transaction frauduleuse (Fraud)
#
# Cela correspond à un problème de classification binaire.
# Comme pour reconnaître des pommes vs oranges → on se base sur des caractéristiques (features) pour classer les exemples.
# 📊 Analyse des données
# 📁 Dataset : creditcard.csv
#
#     Total de lignes : environ 284 807
#
#     Colonnes : 31 (V1 à V28 issues d’un PCA, plus Amount, Time, et Class)
#
#     Variable cible : Class
#
#         0 : Non frauduleux
#
#         1 : Frauduleux
#
# ⚠️ Déséquilibre des classes
#
# Not Fraud: 284,315
# Fraud:        492
#
# 👉 Moins de 0.2% de fraudes. C’est un cas fortement déséquilibré, ce qui peut biaiser l’apprentissage du modèle.
# 🛠 Préparation des données
#
# from sklearn.model_selection import train_test_split
#
# feature_names = df.columns[1:-1]  # Exclut 'Time' et 'Class'
# target = 'Class'
#
# X_train, X_test, y_train, y_test = train_test_split(
#     df[feature_names],
#     df[target],
#     train_size=0.7,
#     test_size=0.3,
#     random_state=1
# )
#
# 🧠 Entraînement du modèle
#
# from sklearn.linear_model import LogisticRegression
#
# model = LogisticRegression()
# model.fit(X_train, y_train.values.ravel())  # y_train → 1D
# pred = model.predict(X_test)
#
# 🧪 Pourquoi choisir la régression logistique ?
#
#     Modèle rapide, interprétable et souvent performant pour les problèmes linéaires binaires
#
#     Fournit directement une probabilité de classe
#
#     Bon point de départ avant d’essayer des modèles plus complexes (SVM, RandomForest...)
#
# 📈 Évaluation – Confusion Matrix
#
# Voici le résumé visuel obtenu :
# 	Prédit : Non Fraud	Prédit : Fraud
# Réel : Non Fraud	85 293	15
# Réel : Fraud	57	78
# 💡 Analyse
#
#     True Negative (TN) : 85 293 → Bonne prédiction de non-fraude
#
#     False Positive (FP) : 15 → Transactions normales mal classées comme fraude
#
#     False Negative (FN) : 57 → Fraudes ratées par le modèle ❗
#
#     True Positive (TP) : 78 → Fraudes détectées ✅
#
# 📏 Métriques clés
#
# Pourquoi ne pas juste se contenter de la "précision" classique ?
#
#     Parce que dans la fraude, mieux vaut rater quelques clients normaux que de laisser passer un fraudeur.
#
# ➕ Recall / Sensibilité
#
# from sklearn.metrics import recall_score
# recall_score(y_test, pred)
#
# Déf. : Pourcentage de fraudes correctement identifiées
# Formule : TP / (TP + FN)
# → Ici : 78 / (78 + 57) ≈ 0.58
# ➕ F1-Score
#
# from sklearn.metrics import f1_score
# f1_score(y_test, pred)
#
# Déf. : Moyenne harmonique entre précision et rappel
# Formule : 2 * (precision * recall) / (precision + recall)
# → Bon compromis pour les jeux déséquilibrés
# ✅ À retenir
#
#     Classification binaire avec données déséquilibrées
#
#     Régression logistique comme point de départ
#
#     Attention à l’évaluation avec Recall et F1-Score
#
#     Il est crucial de minimiser les faux négatifs (FN) dans un contexte de fraude

# %% [markdown]
# 🧠 Fiche Pratique – Détection de Fraude par Carte Bancaire (Credit Card Fraud Detection)
# 🎯 Objectif
#
# Créer un modèle de Machine Learning pour détecter automatiquement les fraudes sur des transactions bancaires.
#
#     Modèle utilisé : Régression Logistique (Logistic Regression)
#
# 📌 Ce que tu vas apprendre
#
#     Comprendre le problème (classification)
#
#     Collecter, préparer et explorer les données
#
#     Entraîner un modèle de classification
#
#     Évaluer les performances avec des métriques adaptées au cas de la fraude
#
# 🧱 Pourquoi c’est un problème de classification ?
#
# Il s’agit de prédire deux classes :
#
#     0 → Transaction légitime (Not Fraud)
#
#     1 → Transaction frauduleuse (Fraud)
#
# Cela correspond à un problème de classification binaire.
# Comme pour reconnaître des pommes vs oranges → on se base sur des caractéristiques (features) pour classer les exemples.
# 📊 Analyse des données
# 📁 Dataset : creditcard.csv
#
#     Total de lignes : environ 284 807
#
#     Colonnes : 31 (V1 à V28 issues d’un PCA, plus Amount, Time, et Class)
#
#     Variable cible : Class
#
#         0 : Non frauduleux
#
#         1 : Frauduleux
#
# ⚠️ Déséquilibre des classes
#
# Not Fraud: 284,315
# Fraud:        492
#
# 👉 Moins de 0.2% de fraudes. C’est un cas fortement déséquilibré, ce qui peut biaiser l’apprentissage du modèle.
# 🛠 Préparation des données
#
# from sklearn.model_selection import train_test_split
#
# feature_names = df.columns[1:-1]  # Exclut 'Time' et 'Class'
# target = 'Class'
#
# X_train, X_test, y_train, y_test = train_test_split(
#     df[feature_names],
#     df[target],
#     train_size=0.7,
#     test_size=0.3,
#     random_state=1
# )
#
# 🧠 Entraînement du modèle
#
# from sklearn.linear_model import LogisticRegression
#
# model = LogisticRegression()
# model.fit(X_train, y_train.values.ravel())  # y_train → 1D
# pred = model.predict(X_test)
#
# 🧪 Pourquoi choisir la régression logistique ?
#
#     Modèle rapide, interprétable et souvent performant pour les problèmes linéaires binaires
#
#     Fournit directement une probabilité de classe
#
#     Bon point de départ avant d’essayer des modèles plus complexes (SVM, RandomForest...)
#
# 📈 Évaluation – Confusion Matrix
#
# Voici le résumé visuel obtenu :
# 	Prédit : Non Fraud	Prédit : Fraud
# Réel : Non Fraud	85 293	15
# Réel : Fraud	57	78
# 💡 Analyse
#
#     True Negative (TN) : 85 293 → Bonne prédiction de non-fraude
#
#     False Positive (FP) : 15 → Transactions normales mal classées comme fraude
#
#     False Negative (FN) : 57 → Fraudes ratées par le modèle ❗
#
#     True Positive (TP) : 78 → Fraudes détectées ✅
#
# 📏 Métriques clés
#
# Pourquoi ne pas juste se contenter de la "précision" classique ?
#
#     Parce que dans la fraude, mieux vaut rater quelques clients normaux que de laisser passer un fraudeur.
#
# ➕ Recall / Sensibilité
#
# from sklearn.metrics import recall_score
# recall_score(y_test, pred)
#
# Déf. : Pourcentage de fraudes correctement identifiées
# Formule : TP / (TP + FN)
# → Ici : 78 / (78 + 57) ≈ 0.58
# ➕ F1-Score
#
# from sklearn.metrics import f1_score
# f1_score(y_test, pred)
#
# Déf. : Moyenne harmonique entre précision et rappel
# Formule : 2 * (precision * recall) / (precision + recall)
# → Bon compromis pour les jeux déséquilibrés
# ✅ À retenir
#
#     Classification binaire avec données déséquilibrées
#
#     Régression logistique comme point de départ
#
#     Attention à l’évaluation avec Recall et F1-Score
#
#     Il est crucial de minimiser les faux négatifs (FN) dans un contexte de fraude

# %% [markdown]
# 🧠 FICHE DE RÉVISION – RÉGRESSION & FONCTIONS DE COÛT
# 🎯 Objectif
#
# Comprendre les bases de la régression, du gradient descent, et des fonctions de perte, afin de :
#
#     Prédire des valeurs continues (régression linéaire)
#
#     Classer des valeurs discrètes (régression logistique)
#
#     Choisir et implémenter la bonne fonction de coût
#
# 🧩 Concepts Clés
# 📌 1. Régression
#
#     Régression Linéaire : prédiction de valeurs continues (ex : prix, température).
#
#     Régression Logistique : prédiction de classes (0 ou 1).
#
# 📌 2. Gradient Descent (Descente de Gradient)
#
#     Algorithme d’optimisation utilisé pour ajuster les paramètres (poids et biais) du modèle afin de minimiser la fonction de perte.
#
# Étapes :
#
#     Initialisation aléatoire des paramètres
#
#     Prédiction & calcul de la perte
#
#     Calcul du gradient
#
#     Mise à jour des poids :
#     θ=θ−α⋅∂J(θ)∂θ
#     θ=θ−α⋅∂θ∂J(θ)​
#
#     Répéter jusqu’à convergence
#
# 📌 3. Fonctions de Perte (Loss Functions)
# Nom	Utilisation	Avantage	Formule
# MSE (Mean Squared Error)	Régression	Sensible aux erreurs	1n∑(yi−y^i)2n1​∑(yi​−y^​i​)2
# MAE (Mean Absolute Error)	Régression	Robuste aux outliers	(\frac{1}{n} \sum
# Cross-Entropy	Classification	Reflète bien l’incertitude	−∑yilog⁡(y^i)−∑yi​log(y^​i​)
# 🏗️ Comparaison : Linéaire vs Logistique
# Type de Régression	Sortie	Tâche	Fonction d’activation
# Linéaire	Réelle (y∈Ry∈R)	Prédiction de valeur	Aucune
# Logistique	Probabilité (0≤y≤10≤y≤1)	Classification binaire	Sigmoïde
# 💻 EXEMPLES DE CODE (VS CODE / NOTEBOOK)
# Régression Linéaire
#
# from sklearn.linear_model import LinearRegression
# import numpy as np
# import matplotlib.pyplot as plt
#
# X = np.array([[1], [2], [3], [4], [5]])
# y = np.array([2, 4, 6, 8, 10])
#
# model = LinearRegression()
# model.fit(X, y)
# preds = model.predict(X)
#
# plt.scatter(X, y, color='blue')
# plt.plot(X, preds, color='red')
# plt.title("Régression Linéaire")
# plt.show()
#
# Régression Logistique
#
# from sklearn.linear_model import LogisticRegression
#
# X = np.array([[1], [2], [3], [4], [5]])
# y = np.array([0, 0, 1, 1, 1])
#
# log_model = LogisticRegression()
# log_model.fit(X, y)
# print("Prédictions :", log_model.predict(X))
#
# Calcul du MSE, MAE, Cross-Entropy
#
# from sklearn.metrics import mean_squared_error, mean_absolute_error, log_loss
#
# y_true = [3, -0.5, 2, 7]
# y_pred = [2.5, 0.0, 2, 8]
# print("MSE:", mean_squared_error(y_true, y_pred))
# print("MAE:", mean_absolute_error(y_true, y_pred))
#
# y_true_class = [0, 1, 1, 0]
# y_probs = [0.1, 0.9, 0.8, 0.3]
# print("Cross-Entropy:", log_loss(y_true_class, y_probs))
#
# Huber Loss (pour outliers)
#
# from sklearn.linear_model import HuberRegressor
#
# X = np.array([[1], [2], [3], [4], [5]])
# y = np.array([2, 4, 6, 8, 50])  # outlier sur 50
#
# huber = HuberRegressor()
# huber.fit(X, y)
# print("Huber Predictions:", huber.predict(X))
#
# 📌 Pourquoi les Fonctions de Perte sont Essentielles
#
#     Guident l’apprentissage (via le gradient)
#
#     Spécifiques à la tâche (classification ≠ régression)
#
#     Influencent les performances du modèle
#
# 🧠 Résumé Mémotechnique
#
#     MSE → Régression précise
#
#     MAE → Régression robuste aux valeurs aberrantes
#
#     Cross-Entropy → Classification binaire/multi-classe
#
#     Gradient Descent → Cherche les bons paramètres pour réduire la perte
#
# 📘 Prochaine étape :
#
#     Apprendre à gérer les données déséquilibrées (comme ton cas de détection de fraude)
#
#     Visualiser les courbes de perte
#
#     Apprendre le ROC AUC, la matrice de confusion, le Recall, Precision, F1-score
#     (utile pour ton projet sur la fraude)
