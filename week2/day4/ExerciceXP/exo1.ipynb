# %% [markdown]
# Exercises XP
#
# Last Updated: January 27th, 2025
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
#
#     The importance of data visualization in data analysis.
#     How to use Python libraries such as Matplotlib and Seaborn for creating effective visualizations.
#     Choosing the right graph for different data types and purposes.
#     Hands-on experience with creating and customizing various types of plots.
#
#
# 🛠️ What you will create
#
#     Line plots for time-series data.
#     Bar charts for category-wise comparisons.
#     Histograms for distribution analysis.
#     Scatter plots for identifying relationships between variables.
#
#
# 🌟 Exercise 1: Understanding Data Visualization
#
#     Task: Explain why data visualization is important in data analysis.
#     Task: Describe the purpose of a line graph in data visualization.
#
#
# 🌟 Exercise 2: Creating a Line Plot for Temperature Variation
#
#     Objective: Create a simple line plot using Matplotlib that represents temperature variations over a week.
#     Tasks:
#     Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]).
#     Label the x-axis as “Day” and the y-axis as “Temperature (°F)”.
#     Add a title to the plot.
#     Display the plot.
#
#
# 🌟 Exercise 3: Visualizing Monthly Sales with a Bar Chart
#
#     Objective: Generate a bar chart using Matplotlib to visualize monthly sales data for a retail store.
#     Tasks:
#     Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]).
#     Label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
#     Add a title to the bar chart.
#     Display the plot.
#
#
# 🌟 Exercise 4: Visualizing the Distribution of CGPA
#
#     Objective: Create a histogram to visualize the distribution of students’ CGPA.
#     Dataset Overview: Assume the CGPA data is categorized into ranges and loaded in a DataFrame named df.
#     Tasks:
#     Import necessary libraries.
#     Use Seaborn’s histplot to create a histogram of the CGPA categories.
#     Customize the histogram with a specific color and add a title.
#     Display the plot.
#
#
# 🌟 Exercise 5: Comparing Anxiety Levels Across Different Genders
#
#     Objective: Use a bar plot to compare the proportion of students experiencing anxiety across different genders.
#     Dataset Overview: The dataset includes columns: ‘Do you have Anxiety?’ and ‘Choose your gender’.
#     Tasks:
#     Import necessary libraries.
#     Use Seaborn to create a bar plot comparing anxiety levels across genders from the dataset df.
#     Customize the plot with an appropriate color palette and add a title.
#     Display the plot.
#
#
# 🌟 Exercise 6: Exploring the Relationship Between Age and Panic Attacks
#
#     Objective: Create a scatter plot to explore the relationship between students’ age and the occurrence of panic attacks.
#     Dataset Overview: The dataset includes columns: ‘Age’ and ‘Do you have Panic Attacks?’.
#     Tasks:
#     Import necessary libraries.
#     Convert panic attack responses to numeric values (e.g., Yes=1, No=0).
#     Use Seaborn’s scatterplot to create a scatter plot with ‘Age’ on the x-axis and numeric panic attack responses on the y-axis.
#     Customize the plot to improve readability by adding labels, a title, and adjusting point styles.
#     Display the plot.

# %% [markdown]
# Exercice 1
#
# pourquoi la visualisation est importante
#
#     permet de voir des tendances qu'on ne remarque pas dans un tableau
#
#     aide à reperer les anomalies
#
#     rend l’analyse plus rapide et compréhensible
#
#     pour présenter les résultats à d’autres
#
# a quoi sert un line plot
#
#     montre une evolution dans le temps
#
#     chaque point est relie au suivant
#
#     pour les donnees chronologiques (ex : temperature par jour, chiffre d’affaires par mois)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from faker import Faker
from faker_commerce import Provider
import random
import calendar
import matplotlib.colors as mcolors
import pandas as pd

# %%
#Exercice 2

x = list(calendar.day_name)
y = list(72, 74, 76, 80, 82, 78, 75)

plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Weekly temperature variation')
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o', markerfacecolor='blue', markersize=12)
plt.tight_layout()
plt.show()

# %%
#Exercice 3

x  = list(calendar.month_name)[1:]
y = list(random.randint(200, 1200) for _ in range(12))

color_list = list(mcolors.CSS4_COLORS.keys())
colors = random.sample(color_list, 12)

plt.bar(x, y, color=colors, edgecolor='black')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Exercice 4

df = pd.read_csv('student_clustering.csv')
""" print(df.head())
print(df.info())
print(df.describe()) """
sns.histplot(df['cgpa'], bins=12, color='mediumseagreen', kde=True)

plt.title('Distribution of Student CGPA')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#Exercie 5

df = pd.read_csv("StudentHealth.csv")

# suppression des lignes où les colonnes concernées sont vides
df = df.dropna(subset=['Do you have Anxiety?', 'Choose your gender'])

# yes à la question sur l'anxiété
anxious = df[df['Do you have Anxiety?'].str.lower() == 'yes']

# genre
gender_counts = anxious['Choose your gender'].value_counts()
""" print(gender_counts) """

# on convertit en proportion
gender_proportions = gender_counts / gender_counts.sum()
""" print(gender_proportions) """

plot_df = gender_proportions.reset_index()
plot_df.columns = ['Gender', 'Proportion']
plot_df['Proportion'] = plot_df['Proportion']*100

sns.barplot(data=plot_df, x='Gender', y='Proportion', hue='Gender', palette='Set2', legend=False)
plt.title("Pourcentage d'anxieux par genre")
plt.xlabel('Genre')
plt.ylabel('Pourcentage')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# %%
# exercice 6
df = pd.read_csv("StudentHealth.csv")

print(df['Age'].describe())
print(df['Age'].unique())

# suppression lignes vides éventuelles
df = df.dropna(subset=['Age', 'Do you have Panic attack?'])

# conversion
df['Panic'] = df['Do you have Panic attack?'].map({'Yes': 1, 'No': 0})

# tranches d'âge
bins = [17, 19, 21, 23, 25]
labels = ['18-19 ans', '20-21 ans', '22-23 ans', '24 ans +']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# moyenne des crises
grouped = df.groupby('Age Group')['Panic'].mean().reset_index()

grouped['Panic'] = grouped['Panic'] * 100
sns.barplot(data=grouped, x='Age Group', y='Panic', palette='viridis')
plt.title("Pourcentage d'étudiants ayant des crises de panique par tranche d'âge")
plt.xlabel("Tranche d'âge")
plt.ylabel("Pourcentage (%)")
plt.ylim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# count    100.00000
# mean      20.53000
# std        2.49628
# min       18.00000
# 25%       18.00000
# 50%       19.00000
# 75%       23.00000
# max       24.00000
# Name: Age, dtype: float64
# [18. 21. 19. 22. 23. 20. 24. nan]
# C:\Users\mathi\AppData\Local\Temp\ipykernel_12856\1132075294.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby('Age Group')['Panic'].mean().reset_index()
# C:\Users\mathi\AppData\Local\Temp\ipykernel_12856\1132075294.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=grouped, x='Age Group', y='Panic', palette='viridis')
