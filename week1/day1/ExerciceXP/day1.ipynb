# %% [markdown]
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
#
#     Basic Python syntax and operations.
#     How to interact with the user through input and output.
#     Working with different data types including lists, tuples, and sets.
#     Conditional statements and loops in Python.
#
#
# 🛠️ What you will create
#
#     Various small programs that demonstrate fundamental programming concepts such as loops, conditions, and data structures.
#
#
# 🌟 Exercise 1 : Hello World
#
# Print the following output in one line of code:
#
# Hello world
# Hello world
# Hello world
# Hello world
#
#
# 🌟 Exercise 2 : Some Math
#
# Write code that calculates the result of: (99^3)*8 (meaning 99 to the power of 3, times 8).
#
#
# 🌟 Exercise 3 : What’s your name ?
#
# Write code that asks the user for their name and determines whether or not you have the same name, print out a funny message based on the outcome.
#
#
# 🌟 Exercise 4 : Tall enough to ride a roller coaster
#
#     Write code that will ask the user for their height in centimeters.
#     If they are over 145cm print a message that states they are tall enough to ride.
#     If they are not tall enough print a message that says they need to grow some more to ride.
#
#
# 🌟 Exercise 5 : Favorite Numbers
#
# Key Python Topics:
#
#     Sets
#     Adding/removing items in a set
#     Set concatenation (using union)
#
#
# Instructions:
#
#     Create a set called my_fav_numbers and populate it with your favorite numbers.
#     Add two new numbers to the set.
#     Remove the last number you added to the set.
#     Create another set called friend_fav_numbers and populate it with your friend’s favorite numbers.
#     Concatenate my_fav_numbers and friend_fav_numbers to create a new set called our_fav_numbers.
#         Note: Sets are unordered collections, so ensure no duplicate numbers are added.
#
#
# 🌟 Exercise 6: Tuple
#
# Key Python Topics:
#
#     Tuples (immutability)
#
#
# Instructions:
#
#     Given a tuple of integers, try to add more integers to the tuple.
#     Hint: Tuples are immutable, meaning they cannot be changed after creation. Think about why you can’t add more integers to a tuple.
#
#
# 🌟 Exercise 7: List Manipulation
#
# Key Python Topics:
#
#     Lists
#     List methods: append, remove, insert, count, clear
#
#
# Instructions:
#
#     You have a list: basket = ["Banana", "Apples", "Oranges", "Blueberries"]
#     Remove "Banana" from the list.
#     Remove "Blueberries" from the list.
#     Add "Kiwi" to the end of the list.
#     Add "Apples" to the beginning of the list.
#     Count how many times "Apples" appear in the list.
#     Empty the list.
#     Print the final state of the list.
#
#
# 🌟 Exercise 8 : Sandwich Orders
#
# Using the list below :
#
# sandwich_orders = ["Tuna sandwich", "Pastrami sandwich", "Avocado sandwich", "Pastrami sandwich", "Egg sandwich", "Chicken sandwich", "Pastrami sandwich"].
#
#     The deli has run out of pastrami, use a while loop to remove all occurrences of Pastrami sandwich from sandwich_orders.
#
#     We need to prepare the orders of the clients:
#
#     Create an empty list called finished_sandwiches.
#     One by one, remove each sandwich from the sandwich_orders while adding them to the finished_sandwiches list.
#     After all the sandwiches have been made, print a message listing each sandwich that was made, such as:
#
#
# I made your tuna sandwich
# I made your avocado sandwich
# I made your egg sandwich
# I made your chicken sandwich

# %%
def afficher_hello_world():
    print(("Hello world\n" * 4).strip())

def calcul_puissance():
    print("Résultat de (99 ** 3) * 8 :", (99 ** 3) * 8)

def comparer_noms():
    my_name = "Jérémy"
    name = input("Comment vous appelez-vous ? ").strip().capitalize()
    if name == my_name:
        print("Trop fort, on a le même nom !")
    else:
        print(f"Enchanté {name}. Je suis {my_name}.")

def verifier_taille():
    while True:
        taille = input("Entrez votre taille en cm : ")
        if taille.isdigit():
            taille = int(taille)
            if taille > 145:
                print("Vous pouvez monter !")
            else:
                print("Désolé, vous êtes trop petit.")
            break
        else:
            print("Veuillez entrer un nombre valide.")

def manipuler_sets():
    my_fav_numbers = {7, 42, 3}
    my_fav_numbers.update({9, 13})
    my_fav_numbers.discard(13)
    friend_fav_numbers = {1, 4, 7}
    our_fav_numbers = my_fav_numbers | friend_fav_numbers
    print("Nos nombres favoris :", our_fav_numbers)

def explication_tuple():
    my_tuple = (1, 2, 3)
    print(my_tuple)
    print("Les tuples sont immuables -> on ne peut pas modifier leur contenu après création.")

def manipuler_liste_panier():
    basket = ["Banana", "Apples", "Oranges", "Blueberries"]
    basket.remove("Banana")
    basket.remove("Blueberries")
    basket.append("Kiwi")
    basket.insert(0, "Apples")
    print("Nombre de pommes :", basket.count("Apples"))
    basket.clear()
    print("Contenu final du panier :", basket)

def gestion_sandwiches():
    sandwich_orders = [
        "Tuna sandwich", "Pastrami sandwich", "Avocado sandwich", 
        "Pastrami sandwich", "Egg sandwich", "Chicken sandwich", 
        "Pastrami sandwich"
    ]

    print("Désolé, plus de sandwich au pastrami.")
    sandwich_orders = [s for s in sandwich_orders if s != "Pastrami sandwich"]

    finished_sandwiches = []
    while sandwich_orders:
        sandwich = sandwich_orders.pop(0)
        print(f"Voici votre {sandwich.lower()}")
        finished_sandwiches.append(sandwich)

afficher_hello_world()
calcul_puissance()
comparer_noms()
verifier_taille()
manipuler_sets()
explication_tuple()
manipuler_liste_panier()
gestion_sandwiches()
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Résultat de (99 ** 3) * 8 : 7762392
# Enchanté Jey. Je suis Jérémy.
# Désolé, vous êtes trop petit.
# Nos nombres favoris : {1, 3, 4, 7, 9, 42}
# (1, 2, 3)
# Les tuples sont immuables -> on ne peut pas modifier leur contenu après création.
# Nombre de pommes : 2
# Contenu final du panier : []
# Désolé, plus de sandwich au pastrami.
# Voici votre tuna sandwich
# Voici votre avocado sandwich
# Voici votre egg sandwich
# Voici votre chicken sandwich
